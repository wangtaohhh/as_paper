# %%
import pyemma.coordinates 

import matplotlib.pyplot as plt
import numpy as np
import mdshare
import pyemma
# for visualization of molecular structures:
import nglview
import mdtraj
from threading import Timer
pdb = mdshare.fetch('alanine-dipeptide-nowater.pdb', working_directory='data')
files = mdshare.fetch('alanine-dipeptide-*-250ns-nowater.xtc', working_directory='data')



feat = pyemma.coordinates.featurizer(pdb)
feat.add_backbone_torsions(periodic=False)

print(feat.describe())

data = pyemma.coordinates.load(files, features=feat)

data_concatenated = np.concatenate(data)
pyemma.plots.plot_feature_histograms(data_concatenated, feature_labels=feat)
# Out:
# ['PHI 0 ALA 2', 'PSI 0 ALA 2']
# Obtaining file info:   0%|                                                                                    …
# getting output of FeatureReader:   0%|                                                                        …
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Feature values'>)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharex=True, sharey=True)
# the * operator used in a function call is used to unpack
# the iterable variable into its single elements.
pyemma.plots.plot_density(*data_concatenated.T, ax=axes[0])
pyemma.plots.plot_free_energy(*data_concatenated.T, ax=axes[1], legacy=False)
for ax in axes.flat:
    ax.set_xlabel('$\Phi$')
    ax.set_aspect('equal')
axes[0].set_ylabel('$\Psi$')
fig.tight_layout()

# %%
feat = pyemma.coordinates.featurizer(pdb)
feat.add_selection(feat.select_Heavy())

data = pyemma.coordinates.load(files, features=feat)
fig, ax = plt.subplots(figsize=(10, 7))
pyemma.plots.plot_feature_histograms(np.concatenate(data), feature_labels=feat, ax=ax)
fig.tight_layout()
# Out:
# Obtaining file info:   0%|                                                                                    …
# getting output of FeatureReader:   0%|                                                                        …

# %%
pdb = mdshare.fetch('alanine-dipeptide-nowater.pdb', working_directory='data')
files = mdshare.fetch('alanine-dipeptide-*-250ns-nowater.xtc', working_directory='data')

feat = pyemma.coordinates.featurizer(pdb)
feat.add_backbone_torsions(periodic=False)
data = pyemma.coordinates.load(files, features=feat)
data_concatenated = np.concatenate(data)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
pyemma.plots.plot_feature_histograms(
    np.concatenate(data), feature_labels=['$\Phi$', '$\Psi$'], ax=axes[0])
pyemma.plots.plot_density(*data_concatenated.T, ax=axes[1], logscale=True)
axes[1].set_xlabel('$\Phi$')
axes[1].set_ylabel('$\Psi$')
fig.tight_layout()
# Out:
# Obtaining file info:   0%|                                                                                    …
# getting output of FeatureReader:   0%|                                                                        …

# %%
cluster_kmeans = pyemma.coordinates.cluster_kmeans(data, k=100, max_iter=50, stride=5)
cluster_regspace = pyemma.coordinates.cluster_regspace(data, dmin=0.3)

fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharex=True, sharey=True)
for ax, cls in zip(axes.flat, [cluster_kmeans, cluster_regspace]):
    pyemma.plots.plot_density(*data_concatenated.T, ax=ax, cbar=False, alpha=0.1, logscale=True)
    ax.scatter(*cls.clustercenters.T, s=15, c='C1')
    ax.set_xlabel('$\Phi$')
    ax.set_ylabel('$\Psi$')
fig.tight_layout()
# Out:
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py:232: PyEMMA_DeprecationWarning: Call to deprecated function "cluster_kmeans". Called from /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py line 232. Use deeptime.clustering.KMeans instead.
#   return caller(func, *(extras + args), **kw)
# initialize kmeans++ centers:   0%|                                                                          | …
# kmeans iterations:   0%|                                                                                     |…
# 14-01-25 14:10:38 pyemma.coordinates.clustering.kmeans.KmeansClustering[3] WARNING  Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/deeptime/clustering/_kmeans.py:466: UserWarning: Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
#   warnings.warn(f"Algorithm did not reach convergence criterion"
# WARNING:pyemma.coordinates.clustering.kmeans.KmeansClustering[3]:Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py:232: PyEMMA_DeprecationWarning: Call to deprecated function "cluster_regspace". Called from /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py line 232. Use deeptime.clustering.RegularSpace instead.
#   return caller(func, *(extras + args), **kw)

# %%
pdb = mdshare.fetch('alanine-dipeptide-nowater.pdb', working_directory='data')
files = mdshare.fetch('alanine-dipeptide-*-250ns-nowater.xtc', working_directory='data')

feat = pyemma.coordinates.featurizer(pdb)
feat.add_backbone_torsions(periodic=False)
data = pyemma.coordinates.load(files, features=feat)
data_concatenated = np.concatenate(data)

cluster = pyemma.coordinates.cluster_kmeans(data, k=200, max_iter=50, stride=10)
its = pyemma.msm.its(cluster.dtrajs, lags=[1, 2, 5, 10, 20, 50], nits=4, errors='bayes')
fig, axes = plt.subplots(1, 3, figsize=(12, 3))
pyemma.plots.plot_feature_histograms(data_concatenated, feature_labels=['$\Phi$', '$\Psi$'], ax=axes[0])
pyemma.plots.plot_density(*data_concatenated.T, ax=axes[1], cbar=False, alpha=0.1)
axes[1].scatter(*cluster.clustercenters.T, s=15, c='C1')
axes[1].set_xlabel('$\Phi$')
axes[1].set_ylabel('$\Psi$')
pyemma.plots.plot_implied_timescales(its, ax=axes[2], units='ps')
fig.tight_layout()
# Out:
# Obtaining file info:   0%|                                                                                    …
# getting output of FeatureReader:   0%|                                                                        …
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py:232: PyEMMA_DeprecationWarning: Call to deprecated function "cluster_kmeans". Called from /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py line 232. Use deeptime.clustering.KMeans instead.
#   return caller(func, *(extras + args), **kw)
# initialize kmeans++ centers:   0%|                                                                          | …
# kmeans iterations:   0%|                                                                                     |…
# 14-01-25 14:25:41 pyemma.coordinates.clustering.kmeans.KmeansClustering[2] WARNING  Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/deeptime/clustering/_kmeans.py:466: UserWarning: Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
#   warnings.warn(f"Algorithm did not reach convergence criterion"
# WARNING:pyemma.coordinates.clustering.kmeans.KmeansClustering[2]:Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/numpy/_core/numeric.py:362: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(a, fill_value, casting='unsafe')
# getting output of KmeansClustering:   0%|                                                                     …
# estimating BayesianMSM:   0%|                                                                                 …

# %%
fig, axes = plt.subplots(2, 3, figsize=(12, 6))
for i, k in enumerate([20, 50, 100]):
    cluster = pyemma.coordinates.cluster_kmeans(data, k=k, max_iter=50, stride=10)
    pyemma.plots.plot_density(*data_concatenated.T, ax=axes[0, i], cbar=False, alpha=0.1)
    axes[0, i].scatter(*cluster.clustercenters.T, s=15, c='C1')
    axes[0, i].set_xlabel('$\Phi$')
    axes[0, i].set_ylabel('$\Psi$')
    axes[0, i].set_title('k = {} centers'.format(k))
    pyemma.plots.plot_implied_timescales(
        pyemma.msm.its(cluster.dtrajs, lags=[1, 2, 5, 10, 20, 50], nits=4, errors='bayes'),
        ax=axes[1, i], units='ps')
    axes[1, i].set_ylim(1, 2000)
fig.tight_layout()
# Out:
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py:232: PyEMMA_DeprecationWarning: Call to deprecated function "cluster_kmeans". Called from /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py line 232. Use deeptime.clustering.KMeans instead.
#   return caller(func, *(extras + args), **kw)
# initialize kmeans++ centers:   0%|                                                                           |…
# kmeans iterations:   0%|                                                                                     |…
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/numpy/_core/numeric.py:362: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(a, fill_value, casting='unsafe')
# getting output of KmeansClustering:   0%|                                                                     …
# estimating BayesianMSM:   0%|                                                                                 …
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py:232: PyEMMA_DeprecationWarning: Call to deprecated function "cluster_kmeans". Called from /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py line 232. Use deeptime.clustering.KMeans instead.
#   return caller(func, *(extras + args), **kw)
# initialize kmeans++ centers:   0%|                                                                           |…
# kmeans iterations:   0%|                                                                                     |…
# 14-01-25 14:26:06 pyemma.coordinates.clustering.kmeans.KmeansClustering[10] WARNING  Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/deeptime/clustering/_kmeans.py:466: UserWarning: Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
#   warnings.warn(f"Algorithm did not reach convergence criterion"
# WARNING:pyemma.coordinates.clustering.kmeans.KmeansClustering[10]:Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/numpy/_core/numeric.py:362: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(a, fill_value, casting='unsafe')
# getting output of KmeansClustering:   0%|                                                                     …
# estimating BayesianMSM:   0%|                                                                                 …
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py:232: PyEMMA_DeprecationWarning: Call to deprecated function "cluster_kmeans". Called from /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py line 232. Use deeptime.clustering.KMeans instead.
#   return caller(func, *(extras + args), **kw)
# initialize kmeans++ centers:   0%|                                                                          | …
# kmeans iterations:   0%|                                                                                     |…
# 14-01-25 14:26:14 pyemma.coordinates.clustering.kmeans.KmeansClustering[14] WARNING  Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/deeptime/clustering/_kmeans.py:466: UserWarning: Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
#   warnings.warn(f"Algorithm did not reach convergence criterion"
# WARNING:pyemma.coordinates.clustering.kmeans.KmeansClustering[14]:Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/numpy/_core/numeric.py:362: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(a, fill_value, casting='unsafe')
# getting output of KmeansClustering:   0%|                                                                     …
# estimating BayesianMSM:   0%|                                                                                 …

# %%
pdb = mdshare.fetch('alanine-dipeptide-nowater.pdb', working_directory='data')
files = mdshare.fetch('alanine-dipeptide-*-250ns-nowater.xtc', working_directory='data')

feat = pyemma.coordinates.featurizer(pdb)
feat.add_backbone_torsions(periodic=False)
data = pyemma.coordinates.load(files, features=feat)
data_concatenated = np.concatenate(data)

cluster = pyemma.coordinates.cluster_kmeans(data, k=100, max_iter=50, stride=10)
dtrajs_concatenated = np.concatenate(cluster.dtrajs)

its = pyemma.msm.its(
    cluster.dtrajs, lags=[1, 2, 5, 10, 20, 50], nits=4, errors='bayes')

fig, axes = plt.subplots(1, 3, figsize=(12, 3))
pyemma.plots.plot_feature_histograms(
    np.concatenate(data), feature_labels=['$\Phi$', '$\Psi$'], ax=axes[0])
pyemma.plots.plot_density(*data_concatenated.T, ax=axes[1], cbar=False, alpha=0.1)
axes[1].scatter(*cluster.clustercenters.T, s=15, c='C1')
axes[1].set_xlabel('$\Phi$')
axes[1].set_ylabel('$\Psi$')
pyemma.plots.plot_implied_timescales(its, ax=axes[2], units='ps')
fig.tight_layout()
msm = pyemma.msm.estimate_markov_model(cluster.dtrajs, lag=10, dt_traj='1 ps')

fig, ax, misc = pyemma.plots.plot_contour(
    *data_concatenated.T, msm.pi[dtrajs_concatenated],
    cbar_label='stationary_distribution',
    method='nearest', mask=True)
ax.scatter(*cluster.clustercenters.T, s=15, c='C1')
ax.set_xlabel('$\Phi$')
ax.set_ylabel('$\Psi$')
fig.tight_layout()
eigvec = msm.eigenvectors_right()
print('first eigenvector is one: {} (min={}, max={})'.format(
    np.allclose(eigvec[:, 0], 1, atol=1e-15), eigvec[:, 0].min(), eigvec[:, 0].max()))

fig, axes = plt.subplots(2, 3, figsize=(12, 6))
for i, ax in enumerate(axes.flat):
    pyemma.plots.plot_contour(
        *data_concatenated.T, eigvec[dtrajs_concatenated, i + 1], ax=ax, cmap='PiYG',
        cbar_label='{}. right eigenvector'.format(i + 2), mask=True)
    ax.scatter(*cluster.clustercenters.T, s=15, c='C1')
    ax.set_xlabel('$\Phi$')
    ax.set_ylabel('$\Psi$')
fig.tight_layout()
# Out:
# Obtaining file info:   0%|                                                                                    …
# getting output of FeatureReader:   0%|                                                                        …
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py:232: PyEMMA_DeprecationWarning: Call to deprecated function "cluster_kmeans". Called from /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/decorator.py line 232. Use deeptime.clustering.KMeans instead.
#   return caller(func, *(extras + args), **kw)
# initialize kmeans++ centers:   0%|                                                                          | …
# kmeans iterations:   0%|                                                                                     |…
# 14-01-25 14:52:56 pyemma.coordinates.clustering.kmeans.KmeansClustering[2] WARNING  Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/deeptime/clustering/_kmeans.py:466: UserWarning: Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
#   warnings.warn(f"Algorithm did not reach convergence criterion"
# WARNING:pyemma.coordinates.clustering.kmeans.KmeansClustering[2]:Algorithm did not reach convergence criterion of 1e-05 in 50 iterations. Consider increasing max_iter.
# /home/tao/miniconda3/envs/nat/lib/python3.9/site-packages/numpy/_core/numeric.py:362: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(a, fill_value, casting='unsafe')
# getting output of KmeansClustering:   0%|                                                                     …
# estimating BayesianMSM:   0%|                                                                                 …
# first eigenvector is one: True (min=0.9999999999999938, max=1.0000000000001132)

# %%
nstates = 4
bayesian_msm = pyemma.msm.bayesian_markov_model(cluster.dtrajs, lag=10, dt_traj='1 ps')
pyemma.plots.plot_cktest(bayesian_msm.cktest(nstates), units='ps');
# Out:
# pyemma.msm.estimators.bayesian_msm.BayesianMSM[7]: Sampling MSMs:   0%|                                     | …
# estimating BayesianMSM:   0%|                                                                                 …
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 nstates = 4
#       2 bayesian_msm = pyemma.msm.bayesian_markov_model(cluster.dtrajs, lag=10, dt_traj='1 ps')
# ----> 3 pyemma.plots.plot_cktest(bayesian_msm.cktest(nstates), units='ps');
#
# File ~/miniconda3/envs/nat/lib/python3.9/site-packages/pyemma/plots/markovtests.py:166, in plot_cktest(cktest, figsize, diag, y01, layout, padding_between, padding_top, units, dt, **plot_kwargs)
#     164     labels.append(predlabel)
#     165     labels.append(estlabel)
# --> 166 fig.legend(handles, labels, 'upper center', ncol=2, frameon=False)
#     167 # change subplot padding
#     168 plt.subplots_adjust(top=1.0-padding_top, wspace=padding_between, hspace=padding_between)
#
# File ~/miniconda3/envs/nat/lib/python3.9/site-packages/matplotlib/figure.py:1076, in FigureBase.legend(self, *args, **kwargs)
#     965 @_docstring.dedent_interpd
#     966 def legend(self, *args, **kwargs):
#     967     """
#     968     Place a legend on the figure.
#     969
#    (...)
#    1073     :ref:`legend_guide` for details.
#    1074     """
# -> 1076     handles, labels, kwargs = mlegend._parse_legend_args(self.axes, *args, **kwargs)
#    1077     # explicitly set the bbox transform if the user hasn't.
#    1078     kwargs.setdefault("bbox_transform", self.transSubfigure)
#
# File ~/miniconda3/envs/nat/lib/python3.9/site-packages/matplotlib/legend.py:1383, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1380     handles, labels = args[:2]
#    1382 else:
# -> 1383     raise _api.nargs_error('legend', '0-2', len(args))
#    1385 return handles, labels, kwargs
#
# TypeError: legend() takes 0-2 positional arguments but 3 were given

# %%
nstates = 6
bayesian_msm = pyemma.msm.bayesian_markov_model(cluster.dtrajs, lag=10, dt_traj='1 ps')
pyemma.plots.plot_cktest(bayesian_msm.cktest(nstates), units='ps');
# Out:
# pyemma.msm.estimators.bayesian_msm.BayesianMSM[10]: Sampling MSMs:   0%|                                    | …
# estimating BayesianMSM:   0%|                                                                                 …
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 nstates = 6
#       2 bayesian_msm = pyemma.msm.bayesian_markov_model(cluster.dtrajs, lag=10, dt_traj='1 ps')
# ----> 3 pyemma.plots.plot_cktest(bayesian_msm.cktest(nstates), units='ps');
#
# File ~/miniconda3/envs/nat/lib/python3.9/site-packages/pyemma/plots/markovtests.py:166, in plot_cktest(cktest, figsize, diag, y01, layout, padding_between, padding_top, units, dt, **plot_kwargs)
#     164     labels.append(predlabel)
#     165     labels.append(estlabel)
# --> 166 fig.legend(handles, labels, 'upper center', ncol=2, frameon=False)
#     167 # change subplot padding
#     168 plt.subplots_adjust(top=1.0-padding_top, wspace=padding_between, hspace=padding_between)
#
# File ~/miniconda3/envs/nat/lib/python3.9/site-packages/matplotlib/figure.py:1076, in FigureBase.legend(self, *args, **kwargs)
#     965 @_docstring.dedent_interpd
#     966 def legend(self, *args, **kwargs):
#     967     """
#     968     Place a legend on the figure.
#     969
#    (...)
#    1073     :ref:`legend_guide` for details.
#    1074     """
# -> 1076     handles, labels, kwargs = mlegend._parse_legend_args(self.axes, *args, **kwargs)
#    1077     # explicitly set the bbox transform if the user hasn't.
#    1078     kwargs.setdefault("bbox_transform", self.transSubfigure)
#
# File ~/miniconda3/envs/nat/lib/python3.9/site-packages/matplotlib/legend.py:1383, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1380     handles, labels = args[:2]
#    1382 else:
# -> 1383     raise _api.nargs_error('legend', '0-2', len(args))
#    1385 return handles, labels, kwargs
#
# TypeError: legend() takes 0-2 positional arguments but 3 were given
